# %% [markdown]
# # Preprocessing

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Path to the folder containing the videos
data_folder = "/content/drive/MyDrive/videos"

# Path to the folder where the training data will be saved
train_folder = "/content/drive/MyDrive/videos_train"

# Path to the folder where the testing data will be saved
test_folder = "/content/drive/MyDrive/videos_test"

# Create the train and test folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get the list of class subfolders
class_folders = [f for f in os.listdir(data_folder) if os.path.isdir(os.path.join(data_folder, f))]

# Iterate over each class folder
for class_folder in class_folders:
    # Path to the current class folder
    class_folder_path = os.path.join(data_folder, class_folder)

    # List all video files in the class folder
    videos = [f for f in os.listdir(class_folder_path) if f.endswith('.mp4')]

    # Perform train-test split for the current class
    try:
        train_videos, test_videos = train_test_split(videos, test_size=0.2, random_state=42)

        # Move the training videos to the train folder
        for train_video in train_videos:
            src = os.path.join(class_folder_path, train_video)
            dst = os.path.join(train_folder, train_video)
            shutil.copy(src, dst)

        # Move the testing videos to the test folder
        for test_video in test_videos:
            src = os.path.join(class_folder_path, test_video)
            dst = os.path.join(test_folder, test_video)
            shutil.copy(src, dst)
# Out:
# Not enough samples in class folder family. Skipping train-test split.
# Not enough samples in class folder color. Skipping train-test split.
# Not enough samples in class folder eat. Skipping train-test split.
# Not enough samples in class folder cook. Skipping train-test split.
# Not enough samples in class folder piano. Skipping train-test split.
# Not enough samples in class folder pick. Skipping train-test split.
# Not enough samples in class folder plate. Skipping train-test split.
# Not enough samples in class folder purpose. Skipping train-test split.
# Not enough samples in class folder race. Skipping train-test split.
# Not enough samples in class folder repeat. Skipping train-test split.
# Not enough samples in class folder replace. Skipping train-test split.
# Not enough samples in class folder report. Skipping train-test split.
# Not enough samples in class folder ring. Skipping train-test split.
# Not enough samples in class folder shampoo. Skipping train-test split.
# Not enough samples in class folder shelf. Skipping train-test split.
# Not enough samples in class folder sign language. Skipping train-test split.
# Not enough samples in class folder similar. Skipping train-test split.
# Not enough samples in class folder skill. Skipping train-test split.
# Not enough samples in class folder strawberry. Skipping train-test split.
# Not enough samples in class folder they. Skipping train-test split.
# Not enough samples in class folder through. Skipping train-test split.
# Not enough samples in class folder toothbrush. Skipping train-test split.
# Not enough samples in class folder true. Skipping train-test split.
# Not enough samples in class folder wall. Skipping train-test split.
# Not enough samples in class folder action. Skipping train-test split.
# Not enough samples in class folder address. Skipping train-test split.
# Not enough samples in class folder agenda. Skipping train-test split.
# Not enough samples in class folder alcohol. Skipping train-test split.
# Not enough samples in class folder amazing. Skipping train-test split.
# Not enough samples in class folder appreciate. Skipping train-test split.
# Not enough samples in class folder around. Skipping train-test split.
# Not enough samples in class folder assistant. Skipping train-test split.
# Not enough samples in class folder attend. Skipping train-test split.
# Not enough samples in class folder babysitter. Skipping train-test split.
# Not enough samples in class folder beginning. Skipping train-test split.
# Not enough samples in class folder bible. Skipping train-test split.
# Not enough samples in class folder bike. Skipping train-test split.
# Not enough samples in class folder bone. Skipping train-test split.
# Not enough samples in class folder bra. Skipping train-test split.
# Not enough samples in class folder bug. Skipping train-test split.
# Not enough samples in class folder button. Skipping train-test split.
# Not enough samples in class folder cabbage. Skipping train-test split.
# Not enough samples in class folder cabinet. Skipping train-test split.
# Not enough samples in class folder cemetery. Skipping train-test split.
# Not enough samples in class folder come here. Skipping train-test split.
# Not enough samples in class folder concept. Skipping train-test split.
# Not enough samples in class folder connect. Skipping train-test split.
# Not enough samples in class folder contract. Skipping train-test split.
# Not enough samples in class folder cross. Skipping train-test split.
# Not enough samples in class folder december. Skipping train-test split.
# Not enough samples in class folder deposit. Skipping train-test split.
# Not enough samples in class folder dime. Skipping train-test split.
# Not enough samples in class folder education. Skipping train-test split.
# Not enough samples in class folder eighteen. Skipping train-test split.
# Not enough samples in class folder eternity. Skipping train-test split.
# Not enough samples in class folder expand. Skipping train-test split.
# Not enough samples in class folder february. Skipping train-test split.
# Not enough samples in class folder final. Skipping train-test split.
# Not enough samples in class folder here. Skipping train-test split.
# Not enough samples in class folder live. Skipping train-test split.
# Not enough samples in class folder pants. Skipping train-test split.
# Not enough samples in class folder since. Skipping train-test split.
# Not enough samples in class folder war. Skipping train-test split.
# Not enough samples in class folder your. Skipping train-test split.
# Not enough samples in class folder bath. Skipping train-test split.
# Not enough samples in class folder hard. Skipping train-test split.
# Not enough samples in class folder kill. Skipping train-test split.
# Not enough samples in class folder thank you. Skipping train-test split.
# Not enough samples in class folder recommend. Skipping train-test split.
# Not enough samples in class folder regular. Skipping train-test split.
# Not enough samples in class folder release. Skipping train-test split.
# Not enough samples in class folder rescue. Skipping train-test split.
# Not enough samples in class folder resist. Skipping train-test split.
# Not enough samples in class folder restroom. Skipping train-test split.
# Not enough samples in class folder robber. Skipping train-test split.
# Not enough samples in class folder salary. Skipping train-test split.
# Not enough samples in class folder saw. Skipping train-test split.
# Not enough samples in class folder scream. Skipping train-test split.
# Not enough samples in class folder sea. Skipping train-test split.
# Not enough samples in class folder seldom. Skipping train-test split.
# Not enough samples in class folder sequence. Skipping train-test split.
# Not enough samples in class folder shovel. Skipping train-test split.
# Not enough samples in class folder singer. Skipping train-test split.
# Not enough samples in class folder ski. Skipping train-test split.
# Not enough samples in class folder skip. Skipping train-test split.
# Not enough samples in class folder spill. Skipping train-test split.
# Not enough samples in class folder spit. Skipping train-test split.
# Not enough samples in class folder squeeze. Skipping train-test split.
# Not enough samples in class folder stepfather. Skipping train-test split.
# Not enough samples in class folder sting. Skipping train-test split.
# Not enough samples in class folder stir. Skipping train-test split.
# Not enough samples in class folder stitch. Skipping train-test split.
# Not enough samples in class folder swimming. Skipping train-test split.
# Not enough samples in class folder talent. Skipping train-test split.
# Not enough samples in class folder tempt. Skipping train-test split.
# Not enough samples in class folder than. Skipping train-test split.
# Not enough samples in class folder tobacco. Skipping train-test split.
# Not enough samples in class folder toilet paper. Skipping train-test split.
# Not enough samples in class folder tolerate. Skipping train-test split.
# Not enough samples in class folder towel. Skipping train-test split.
# Not enough samples in class folder tv. Skipping train-test split.
# Not enough samples in class folder vampire. Skipping train-test split.
# Not enough samples in class folder viewpoint. Skipping train-test split.
# Not enough samples in class folder volleyball. Skipping train-test split.
# Not enough samples in class folder washington. Skipping train-test split.
# Not enough samples in class folder weigh. Skipping train-test split.
# Not enough samples in class folder any. Skipping train-test split.
# Not enough samples in class folder asl. Skipping train-test split.
# Not enough samples in class folder belt. Skipping train-test split.
# Not enough samples in class folder both. Skipping train-test split.
# Not enough samples in class folder challenge. Skipping train-test split.
# Not enough samples in class folder chocolate. Skipping train-test split.
# Not enough samples in class folder cloud. Skipping train-test split.
# Not enough samples in class folder continue. Skipping train-test split.
# Not enough samples in class folder corner. Skipping train-test split.
# Not enough samples in class folder dead. Skipping train-test split.
# Not enough samples in class folder depend. Skipping train-test split.
# Not enough samples in class folder develop. Skipping train-test split.
# Not enough samples in class folder duty. Skipping train-test split.
# Not enough samples in class folder elevator. Skipping train-test split.
# Not enough samples in class folder email. Skipping train-test split.
# Not enough samples in class folder europe. Skipping train-test split.
# Not enough samples in class folder event. Skipping train-test split.
# Not enough samples in class folder flag. Skipping train-test split.
# Not enough samples in class folder form. Skipping train-test split.
# Not enough samples in class folder god. Skipping train-test split.
# Not enough samples in class folder guess. Skipping train-test split.
# Not enough samples in class folder high. Skipping train-test split.
# Not enough samples in class folder history. Skipping train-test split.
# Not enough samples in class folder introduce. Skipping train-test split.
# Not enough samples in class folder lazy. Skipping train-test split.
# Not enough samples in class folder love. Skipping train-test split.
# Not enough samples in class folder magazine. Skipping train-test split.
# Not enough samples in class folder number. Skipping train-test split.
# Not enough samples in class folder cry. Skipping train-test split.
# Not enough samples in class folder green. Skipping train-test split.
# Not enough samples in class folder buy. Skipping train-test split.
# Not enough samples in class folder cute. Skipping train-test split.
# Not enough samples in class folder know. Skipping train-test split.
# Not enough samples in class folder old. Skipping train-test split.
# Not enough samples in class folder stay. Skipping train-test split.
# Not enough samples in class folder window. Skipping train-test split.
# Not enough samples in class folder beard. Skipping train-test split.
# Not enough samples in class folder fat. Skipping train-test split.

# %%
import os
import cv2
import shutil
from sklearn.model_selection import train_test_split

# Path to the folder containing the videos
data_folder = "/content/drive/MyDrive/videos"

# Path to the folder where the training data will be saved
train_folder = "/content/drive/MyDrive/videos_train"

# Path to the folder where the testing data will be saved
test_folder = "/content/drive/MyDrive/videos_test"

# Create the train and test folders if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get the list of video files
videos = [f for f in os.listdir(data_folder) if f.endswith('.mp4')]

# Perform train-test split on the videos
train_videos, test_videos = train_test_split(videos, test_size=0.2, random_state=42)

# Function to extract frames from a video and save them in the specified folder
def extract_frames(video_path, output_folder):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Read the first frame
    ret, frame = cap.read()
    frame_count = 0

    # Loop through all frames and save them as images
    while ret:
        # Save the frame as an image
        frame_path = os.path.join(output_folder, f"frame_{frame_count}.jpg")
        cv2.imwrite(frame_path, frame)

        # Read the next frame
        ret, frame = cap.read()
        frame_count += 1

    # Release the video capture object
    cap.release()

# Iterate over the training videos and extract frames
for train_video in train_videos:
    video_path = os.path.join(data_folder, train_video)
    output_folder = os.path.join(train_folder, os.path.splitext(train_video)[0])
    extract_frames(video_path, output_folder)

# Iterate over the testing videos and extract frames
for test_video in test_videos:
    video_path = os.path.join(data_folder, test_video)
    output_folder = os.path.join(test_folder, os.path.splitext(test_video)[0])
    extract_frames(video_path, output_folder)

# %%
import os
import cv2

# Define the path to the folder containing the video folders
data_path = "/content/drive/MyDrive/videos"

# Loop through each folder and convert videos to frames
for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    if not os.path.isdir(folder_path):  # Check if the path is a directory
        continue
    output_folder = os.path.join(data_path, f"{folder}_frames")
    os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist
    for video_file in os.listdir(folder_path):
        video_path = os.path.join(folder_path, video_file)
        if not os.path.isfile(video_path):  # Check if the path is a file
            continue
        # Read the video
        cap = cv2.VideoCapture(video_path)
        frame_count = 0
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            # Save the frame as an image
            frame_file = f"{video_file}_frame{frame_count}.jpg"
            frame_path = os.path.join(output_folder, frame_file)
            cv2.imwrite(frame_path, frame)
            frame_count += 1
        cap.release()
        print(f"Converted {frame_count} frames from {video_path}")

# %%
import os
import shutil

# Define the path to the folder containing the video folders
data_path = "/content/drive/MyDrive/videos"

# Create a new folder to store the separated "_frames" folders
output_path = os.path.join(data_path, "frames_folders")
os.makedirs(output_path, exist_ok=True)

# Loop through each folder and separate the "_frames" folders
for folder in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder)
    if not os.path.isdir(folder_path):  # Check if the path is a directory
        continue
    if folder.endswith("_frames"):
        # Move the "_frames" folder to the separate output folder
        new_folder_path = os.path.join(output_path, folder)
        shutil.move(folder_path, new_folder_path)
        print(f"Moved folder {folder} to {new_folder_path}")
# Out:
# Moved folder wall_frames to /content/drive/MyDrive/videos/frames_folders/wall_frames
# Moved folder yesterday_frames to /content/drive/MyDrive/videos/frames_folders/yesterday_frames
# Moved folder yellow_frames to /content/drive/MyDrive/videos/frames_folders/yellow_frames
# Moved folder book_frames to /content/drive/MyDrive/videos/frames_folders/book_frames
# Moved folder drink_frames to /content/drive/MyDrive/videos/frames_folders/drink_frames
# Moved folder computer_frames to /content/drive/MyDrive/videos/frames_folders/computer_frames
# Moved folder before_frames to /content/drive/MyDrive/videos/frames_folders/before_frames
# Moved folder chair_frames to /content/drive/MyDrive/videos/frames_folders/chair_frames
# Moved folder go_frames to /content/drive/MyDrive/videos/frames_folders/go_frames
# Moved folder clothes_frames to /content/drive/MyDrive/videos/frames_folders/clothes_frames
# Moved folder who_frames to /content/drive/MyDrive/videos/frames_folders/who_frames
# Moved folder candy_frames to /content/drive/MyDrive/videos/frames_folders/candy_frames
# Moved folder cousin_frames to /content/drive/MyDrive/videos/frames_folders/cousin_frames
# Moved folder deaf_frames to /content/drive/MyDrive/videos/frames_folders/deaf_frames
# Moved folder fine_frames to /content/drive/MyDrive/videos/frames_folders/fine_frames
# Moved folder help_frames to /content/drive/MyDrive/videos/frames_folders/help_frames
# Moved folder no_frames to /content/drive/MyDrive/videos/frames_folders/no_frames
# Moved folder thin_frames to /content/drive/MyDrive/videos/frames_folders/thin_frames
# Moved folder walk_frames to /content/drive/MyDrive/videos/frames_folders/walk_frames
# Moved folder year_frames to /content/drive/MyDrive/videos/frames_folders/year_frames
# Moved folder yes_frames to /content/drive/MyDrive/videos/frames_folders/yes_frames
# Moved folder all_frames to /content/drive/MyDrive/videos/frames_folders/all_frames
# Moved folder black_frames to /content/drive/MyDrive/videos/frames_folders/black_frames
# Moved folder cool_frames to /content/drive/MyDrive/videos/frames_folders/cool_frames
# Moved folder finish_frames to /content/drive/MyDrive/videos/frames_folders/finish_frames
# Moved folder hot_frames to /content/drive/MyDrive/videos/frames_folders/hot_frames
# Moved folder like_frames to /content/drive/MyDrive/videos/frames_folders/like_frames
# Moved folder many_frames to /content/drive/MyDrive/videos/frames_folders/many_frames
# Moved folder mother_frames to /content/drive/MyDrive/videos/frames_folders/mother_frames
# Moved folder now_frames to /content/drive/MyDrive/videos/frames_folders/now_frames
# Moved folder orange_frames to /content/drive/MyDrive/videos/frames_folders/orange_frames
# Moved folder table_frames to /content/drive/MyDrive/videos/frames_folders/table_frames
# Moved folder thanksgiving_frames to /content/drive/MyDrive/videos/frames_folders/thanksgiving_frames
# Moved folder what_frames to /content/drive/MyDrive/videos/frames_folders/what_frames
# Moved folder woman_frames to /content/drive/MyDrive/videos/frames_folders/woman_frames
# Moved folder bed_frames to /content/drive/MyDrive/videos/frames_folders/bed_frames
# Moved folder blue_frames to /content/drive/MyDrive/videos/frames_folders/blue_frames
# Moved folder bowling_frames to /content/drive/MyDrive/videos/frames_folders/bowling_frames
# Moved folder can_frames to /content/drive/MyDrive/videos/frames_folders/can_frames
# Moved folder dog_frames to /content/drive/MyDrive/videos/frames_folders/dog_frames
# Moved folder family_frames to /content/drive/MyDrive/videos/frames_folders/family_frames
# Moved folder fish_frames to /content/drive/MyDrive/videos/frames_folders/fish_frames
# Moved folder graduate_frames to /content/drive/MyDrive/videos/frames_folders/graduate_frames
# Moved folder hat_frames to /content/drive/MyDrive/videos/frames_folders/hat_frames
# Moved folder hearing_frames to /content/drive/MyDrive/videos/frames_folders/hearing_frames
# Moved folder kiss_frames to /content/drive/MyDrive/videos/frames_folders/kiss_frames
# Moved folder language_frames to /content/drive/MyDrive/videos/frames_folders/language_frames
# Moved folder later_frames to /content/drive/MyDrive/videos/frames_folders/later_frames
# Moved folder man_frames to /content/drive/MyDrive/videos/frames_folders/man_frames
# Moved folder shirt_frames to /content/drive/MyDrive/videos/frames_folders/shirt_frames
# Moved folder study_frames to /content/drive/MyDrive/videos/frames_folders/study_frames
# Moved folder tall_frames to /content/drive/MyDrive/videos/frames_folders/tall_frames
# Moved folder white_frames to /content/drive/MyDrive/videos/frames_folders/white_frames
# Moved folder wrong_frames to /content/drive/MyDrive/videos/frames_folders/wrong_frames
# Moved folder accident_frames to /content/drive/MyDrive/videos/frames_folders/accident_frames
# Moved folder apple_frames to /content/drive/MyDrive/videos/frames_folders/apple_frames
# Moved folder bird_frames to /content/drive/MyDrive/videos/frames_folders/bird_frames
# Moved folder change_frames to /content/drive/MyDrive/videos/frames_folders/change_frames
# Moved folder color_frames to /content/drive/MyDrive/videos/frames_folders/color_frames
# Moved folder corn_frames to /content/drive/MyDrive/videos/frames_folders/corn_frames
# Moved folder cow_frames to /content/drive/MyDrive/videos/frames_folders/cow_frames
# Moved folder dance_frames to /content/drive/MyDrive/videos/frames_folders/dance_frames
# Moved folder dark_frames to /content/drive/MyDrive/videos/frames_folders/dark_frames
# Moved folder doctor_frames to /content/drive/MyDrive/videos/frames_folders/doctor_frames
# Moved folder eat_frames to /content/drive/MyDrive/videos/frames_folders/eat_frames
# Moved folder enjoy_frames to /content/drive/MyDrive/videos/frames_folders/enjoy_frames
# Moved folder forget_frames to /content/drive/MyDrive/videos/frames_folders/forget_frames
# Moved folder give_frames to /content/drive/MyDrive/videos/frames_folders/give_frames
# Moved folder last_frames to /content/drive/MyDrive/videos/frames_folders/last_frames
# Moved folder meet_frames to /content/drive/MyDrive/videos/frames_folders/meet_frames
# Moved folder pink_frames to /content/drive/MyDrive/videos/frames_folders/pink_frames
# Moved folder pizza_frames to /content/drive/MyDrive/videos/frames_folders/pizza_frames
# Moved folder play_frames to /content/drive/MyDrive/videos/frames_folders/play_frames
# Moved folder school_frames to /content/drive/MyDrive/videos/frames_folders/school_frames
# Moved folder secretary_frames to /content/drive/MyDrive/videos/frames_folders/secretary_frames
# Moved folder short_frames to /content/drive/MyDrive/videos/frames_folders/short_frames
# Moved folder time_frames to /content/drive/MyDrive/videos/frames_folders/time_frames
# Moved folder want_frames to /content/drive/MyDrive/videos/frames_folders/want_frames
# Moved folder work_frames to /content/drive/MyDrive/videos/frames_folders/work_frames
# Moved folder africa_frames to /content/drive/MyDrive/videos/frames_folders/africa_frames
# Moved folder basketball_frames to /content/drive/MyDrive/videos/frames_folders/basketball_frames
# Moved folder birthday_frames to /content/drive/MyDrive/videos/frames_folders/birthday_frames
# Moved folder brown_frames to /content/drive/MyDrive/videos/frames_folders/brown_frames
# Moved folder but_frames to /content/drive/MyDrive/videos/frames_folders/but_frames
# Moved folder cheat_frames to /content/drive/MyDrive/videos/frames_folders/cheat_frames
# Moved folder city_frames to /content/drive/MyDrive/videos/frames_folders/city_frames
# Moved folder cook_frames to /content/drive/MyDrive/videos/frames_folders/cook_frames
# Moved folder decide_frames to /content/drive/MyDrive/videos/frames_folders/decide_frames
# Moved folder full_frames to /content/drive/MyDrive/videos/frames_folders/full_frames
# Moved folder how_frames to /content/drive/MyDrive/videos/frames_folders/how_frames
# Moved folder jacket_frames to /content/drive/MyDrive/videos/frames_folders/jacket_frames
# Moved folder letter_frames to /content/drive/MyDrive/videos/frames_folders/letter_frames
# Moved folder medicine_frames to /content/drive/MyDrive/videos/frames_folders/medicine_frames
# Moved folder need_frames to /content/drive/MyDrive/videos/frames_folders/need_frames
# Moved folder percent_frames to /content/drive/MyDrive/videos/frames_folders/percent_frames
# Moved folder physics_frames to /content/drive/MyDrive/videos/frames_folders/physics_frames
# Moved folder piano_frames to /content/drive/MyDrive/videos/frames_folders/piano_frames
# Moved folder pick_frames to /content/drive/MyDrive/videos/frames_folders/pick_frames
# Moved folder pie_frames to /content/drive/MyDrive/videos/frames_folders/pie_frames
# Moved folder plate_frames to /content/drive/MyDrive/videos/frames_folders/plate_frames
# Moved folder pocket_frames to /content/drive/MyDrive/videos/frames_folders/pocket_frames
# Moved folder popcorn_frames to /content/drive/MyDrive/videos/frames_folders/popcorn_frames
# Moved folder positive_frames to /content/drive/MyDrive/videos/frames_folders/positive_frames
# Moved folder pregnant_frames to /content/drive/MyDrive/videos/frames_folders/pregnant_frames
# Moved folder prevent_frames to /content/drive/MyDrive/videos/frames_folders/prevent_frames
# Moved folder proof_frames to /content/drive/MyDrive/videos/frames_folders/proof_frames
# Moved folder pumpkin_frames to /content/drive/MyDrive/videos/frames_folders/pumpkin_frames
# Moved folder purpose_frames to /content/drive/MyDrive/videos/frames_folders/purpose_frames
# Moved folder race_frames to /content/drive/MyDrive/videos/frames_folders/race_frames
# Moved folder realize_frames to /content/drive/MyDrive/videos/frames_folders/realize_frames
# Moved folder recognize_frames to /content/drive/MyDrive/videos/frames_folders/recognize_frames
# Moved folder refuse_frames to /content/drive/MyDrive/videos/frames_folders/refuse_frames
# Moved folder relationship_frames to /content/drive/MyDrive/videos/frames_folders/relationship_frames
# Moved folder repeat_frames to /content/drive/MyDrive/videos/frames_folders/repeat_frames
# Moved folder replace_frames to /content/drive/MyDrive/videos/frames_folders/replace_frames
# Moved folder report_frames to /content/drive/MyDrive/videos/frames_folders/report_frames
# Moved folder represent_frames to /content/drive/MyDrive/videos/frames_folders/represent_frames
# Moved folder request_frames to /content/drive/MyDrive/videos/frames_folders/request_frames
# Moved folder responsibility_frames to /content/drive/MyDrive/videos/frames_folders/responsibility_frames
# Moved folder result_frames to /content/drive/MyDrive/videos/frames_folders/result_frames
# Moved folder reveal_frames to /content/drive/MyDrive/videos/frames_folders/reveal_frames
# Moved folder ring_frames to /content/drive/MyDrive/videos/frames_folders/ring_frames
# Moved folder rob_frames to /content/drive/MyDrive/videos/frames_folders/rob_frames
# Moved folder rock_frames to /content/drive/MyDrive/videos/frames_folders/rock_frames
# Moved folder role_frames to /content/drive/MyDrive/videos/frames_folders/role_frames
# Moved folder rope_frames to /content/drive/MyDrive/videos/frames_folders/rope_frames
# Moved folder rush_frames to /content/drive/MyDrive/videos/frames_folders/rush_frames
# Moved folder salute_frames to /content/drive/MyDrive/videos/frames_folders/salute_frames
# Moved folder satisfy_frames to /content/drive/MyDrive/videos/frames_folders/satisfy_frames
# Moved folder search_frames to /content/drive/MyDrive/videos/frames_folders/search_frames
# Moved folder selfish_frames to /content/drive/MyDrive/videos/frames_folders/selfish_frames
# Moved folder sensitive_frames to /content/drive/MyDrive/videos/frames_folders/sensitive_frames
# Moved folder serve_frames to /content/drive/MyDrive/videos/frames_folders/serve_frames
# Moved folder seven_frames to /content/drive/MyDrive/videos/frames_folders/seven_frames
# Moved folder shampoo_frames to /content/drive/MyDrive/videos/frames_folders/shampoo_frames
# Moved folder she_frames to /content/drive/MyDrive/videos/frames_folders/she_frames
# Moved folder shelf_frames to /content/drive/MyDrive/videos/frames_folders/shelf_frames
# Moved folder shopping_frames to /content/drive/MyDrive/videos/frames_folders/shopping_frames
# Moved folder sign language_frames to /content/drive/MyDrive/videos/frames_folders/sign language_frames
# Moved folder similar_frames to /content/drive/MyDrive/videos/frames_folders/similar_frames
# Moved folder sing_frames to /content/drive/MyDrive/videos/frames_folders/sing_frames
# Moved folder six_frames to /content/drive/MyDrive/videos/frames_folders/six_frames
# Moved folder skeleton_frames to /content/drive/MyDrive/videos/frames_folders/skeleton_frames
# Moved folder sketch_frames to /content/drive/MyDrive/videos/frames_folders/sketch_frames
# Moved folder skill_frames to /content/drive/MyDrive/videos/frames_folders/skill_frames
# Moved folder sleepy_frames to /content/drive/MyDrive/videos/frames_folders/sleepy_frames
# Moved folder slip_frames to /content/drive/MyDrive/videos/frames_folders/slip_frames
# Moved folder smell_frames to /content/drive/MyDrive/videos/frames_folders/smell_frames
# Moved folder sneeze_frames to /content/drive/MyDrive/videos/frames_folders/sneeze_frames
# Moved folder snob_frames to /content/drive/MyDrive/videos/frames_folders/snob_frames
# Moved folder specific_frames to /content/drive/MyDrive/videos/frames_folders/specific_frames
# Moved folder stamp_frames to /content/drive/MyDrive/videos/frames_folders/stamp_frames
# Moved folder steel_frames to /content/drive/MyDrive/videos/frames_folders/steel_frames
# Moved folder strawberry_frames to /content/drive/MyDrive/videos/frames_folders/strawberry_frames
# Moved folder subtract_frames to /content/drive/MyDrive/videos/frames_folders/subtract_frames
# Moved folder subway_frames to /content/drive/MyDrive/videos/frames_folders/subway_frames
# Moved folder suffer_frames to /content/drive/MyDrive/videos/frames_folders/suffer_frames
# Moved folder surface_frames to /content/drive/MyDrive/videos/frames_folders/surface_frames
# Moved folder sweep_frames to /content/drive/MyDrive/videos/frames_folders/sweep_frames
# Moved folder swing_frames to /content/drive/MyDrive/videos/frames_folders/swing_frames
# Moved folder switzerland_frames to /content/drive/MyDrive/videos/frames_folders/switzerland_frames
# Moved folder tale_frames to /content/drive/MyDrive/videos/frames_folders/tale_frames
# Moved folder tan_frames to /content/drive/MyDrive/videos/frames_folders/tan_frames
# Moved folder teeth_frames to /content/drive/MyDrive/videos/frames_folders/teeth_frames
# Moved folder terrible_frames to /content/drive/MyDrive/videos/frames_folders/terrible_frames
# Moved folder thankful_frames to /content/drive/MyDrive/videos/frames_folders/thankful_frames
# Moved folder they_frames to /content/drive/MyDrive/videos/frames_folders/they_frames
# Moved folder through_frames to /content/drive/MyDrive/videos/frames_folders/through_frames
# Moved folder tiptoe_frames to /content/drive/MyDrive/videos/frames_folders/tiptoe_frames
# Moved folder title_frames to /content/drive/MyDrive/videos/frames_folders/title_frames
# Moved folder tooth_frames to /content/drive/MyDrive/videos/frames_folders/tooth_frames
# Moved folder toothbrush_frames to /content/drive/MyDrive/videos/frames_folders/toothbrush_frames
# Moved folder total_frames to /content/drive/MyDrive/videos/frames_folders/total_frames
# Moved folder tough_frames to /content/drive/MyDrive/videos/frames_folders/tough_frames
# Moved folder tradition_frames to /content/drive/MyDrive/videos/frames_folders/tradition_frames
# Moved folder trophy_frames to /content/drive/MyDrive/videos/frames_folders/trophy_frames
# Moved folder trouble_frames to /content/drive/MyDrive/videos/frames_folders/trouble_frames
# Moved folder true_frames to /content/drive/MyDrive/videos/frames_folders/true_frames
# Moved folder trust_frames to /content/drive/MyDrive/videos/frames_folders/trust_frames
# Moved folder under_frames to /content/drive/MyDrive/videos/frames_folders/under_frames
# Moved folder verb_frames to /content/drive/MyDrive/videos/frames_folders/verb_frames
# Moved folder watermelon_frames to /content/drive/MyDrive/videos/frames_folders/watermelon_frames
# Moved folder way_frames to /content/drive/MyDrive/videos/frames_folders/way_frames
# Moved folder weird_frames to /content/drive/MyDrive/videos/frames_folders/weird_frames
# Moved folder while_frames to /content/drive/MyDrive/videos/frames_folders/while_frames
# Moved folder wide_frames to /content/drive/MyDrive/videos/frames_folders/wide_frames
# Moved folder willing_frames to /content/drive/MyDrive/videos/frames_folders/willing_frames
# Moved folder wish_frames to /content/drive/MyDrive/videos/frames_folders/wish_frames
# Moved folder wonderful_frames to /content/drive/MyDrive/videos/frames_folders/wonderful_frames
# Moved folder workshop_frames to /content/drive/MyDrive/videos/frames_folders/workshop_frames
# Moved folder worse_frames to /content/drive/MyDrive/videos/frames_folders/worse_frames
# Moved folder wrench_frames to /content/drive/MyDrive/videos/frames_folders/wrench_frames
# Moved folder a_frames to /content/drive/MyDrive/videos/frames_folders/a_frames
# Moved folder a lot_frames to /content/drive/MyDrive/videos/frames_folders/a lot_frames
# Moved folder abdomen_frames to /content/drive/MyDrive/videos/frames_folders/abdomen_frames
# Moved folder able_frames to /content/drive/MyDrive/videos/frames_folders/able_frames
# Moved folder accountant_frames to /content/drive/MyDrive/videos/frames_folders/accountant_frames
# Moved folder action_frames to /content/drive/MyDrive/videos/frames_folders/action_frames
# Moved folder active_frames to /content/drive/MyDrive/videos/frames_folders/active_frames
# Moved folder activity_frames to /content/drive/MyDrive/videos/frames_folders/activity_frames
# Moved folder address_frames to /content/drive/MyDrive/videos/frames_folders/address_frames
# Moved folder affect_frames to /content/drive/MyDrive/videos/frames_folders/affect_frames
# Moved folder afraid_frames to /content/drive/MyDrive/videos/frames_folders/afraid_frames
# Moved folder against_frames to /content/drive/MyDrive/videos/frames_folders/against_frames
# Moved folder agenda_frames to /content/drive/MyDrive/videos/frames_folders/agenda_frames
# Moved folder ahead_frames to /content/drive/MyDrive/videos/frames_folders/ahead_frames
# Moved folder aim_frames to /content/drive/MyDrive/videos/frames_folders/aim_frames
# Moved folder alcohol_frames to /content/drive/MyDrive/videos/frames_folders/alcohol_frames
# Moved folder algebra_frames to /content/drive/MyDrive/videos/frames_folders/algebra_frames
# Moved folder all day_frames to /content/drive/MyDrive/videos/frames_folders/all day_frames
# Moved folder amazing_frames to /content/drive/MyDrive/videos/frames_folders/amazing_frames
# Moved folder angle_frames to /content/drive/MyDrive/videos/frames_folders/angle_frames
# Moved folder apart_frames to /content/drive/MyDrive/videos/frames_folders/apart_frames
# Moved folder apostrophe_frames to /content/drive/MyDrive/videos/frames_folders/apostrophe_frames
# Moved folder appetite_frames to /content/drive/MyDrive/videos/frames_folders/appetite_frames
# Moved folder appreciate_frames to /content/drive/MyDrive/videos/frames_folders/appreciate_frames
# Moved folder april_frames to /content/drive/MyDrive/videos/frames_folders/april_frames
# Moved folder archery_frames to /content/drive/MyDrive/videos/frames_folders/archery_frames
# Moved folder around_frames to /content/drive/MyDrive/videos/frames_folders/around_frames
# Moved folder article_frames to /content/drive/MyDrive/videos/frames_folders/article_frames
# Moved folder assistant_frames to /content/drive/MyDrive/videos/frames_folders/assistant_frames
# Moved folder attend_frames to /content/drive/MyDrive/videos/frames_folders/attend_frames
# Moved folder auction_frames to /content/drive/MyDrive/videos/frames_folders/auction_frames
# Moved folder authority_frames to /content/drive/MyDrive/videos/frames_folders/authority_frames
# Moved folder average_frames to /content/drive/MyDrive/videos/frames_folders/average_frames
# Moved folder awake_frames to /content/drive/MyDrive/videos/frames_folders/awake_frames
# Moved folder b_frames to /content/drive/MyDrive/videos/frames_folders/b_frames
# Moved folder babysitter_frames to /content/drive/MyDrive/videos/frames_folders/babysitter_frames
# Moved folder battle_frames to /content/drive/MyDrive/videos/frames_folders/battle_frames
# Moved folder beginning_frames to /content/drive/MyDrive/videos/frames_folders/beginning_frames
# Moved folder belief_frames to /content/drive/MyDrive/videos/frames_folders/belief_frames
# Moved folder bible_frames to /content/drive/MyDrive/videos/frames_folders/bible_frames
# Moved folder bike_frames to /content/drive/MyDrive/videos/frames_folders/bike_frames
# Moved folder blend_frames to /content/drive/MyDrive/videos/frames_folders/blend_frames
# Moved folder bone_frames to /content/drive/MyDrive/videos/frames_folders/bone_frames
# Moved folder bra_frames to /content/drive/MyDrive/videos/frames_folders/bra_frames
# Moved folder brief_frames to /content/drive/MyDrive/videos/frames_folders/brief_frames
# Moved folder broke_frames to /content/drive/MyDrive/videos/frames_folders/broke_frames
# Moved folder bug_frames to /content/drive/MyDrive/videos/frames_folders/bug_frames
# Moved folder bully_frames to /content/drive/MyDrive/videos/frames_folders/bully_frames
# Moved folder button_frames to /content/drive/MyDrive/videos/frames_folders/button_frames
# Moved folder cabbage_frames to /content/drive/MyDrive/videos/frames_folders/cabbage_frames
# Moved folder cabinet_frames to /content/drive/MyDrive/videos/frames_folders/cabinet_frames
# Moved folder calculate_frames to /content/drive/MyDrive/videos/frames_folders/calculate_frames
# Moved folder calculator_frames to /content/drive/MyDrive/videos/frames_folders/calculator_frames
# Moved folder calculus_frames to /content/drive/MyDrive/videos/frames_folders/calculus_frames
# Moved folder camping_frames to /content/drive/MyDrive/videos/frames_folders/camping_frames
# Moved folder canoe_frames to /content/drive/MyDrive/videos/frames_folders/canoe_frames
# Moved folder careless_frames to /content/drive/MyDrive/videos/frames_folders/careless_frames
# Moved folder ceiling_frames to /content/drive/MyDrive/videos/frames_folders/ceiling_frames
# Moved folder cemetery_frames to /content/drive/MyDrive/videos/frames_folders/cemetery_frames
# Moved folder chapter_frames to /content/drive/MyDrive/videos/frames_folders/chapter_frames
# Moved folder choir_frames to /content/drive/MyDrive/videos/frames_folders/choir_frames
# Moved folder circle_frames to /content/drive/MyDrive/videos/frames_folders/circle_frames
# Moved folder come_frames to /content/drive/MyDrive/videos/frames_folders/come_frames
# Moved folder come here_frames to /content/drive/MyDrive/videos/frames_folders/come here_frames
# Moved folder company_frames to /content/drive/MyDrive/videos/frames_folders/company_frames
# Moved folder complete_frames to /content/drive/MyDrive/videos/frames_folders/complete_frames
# Moved folder concept_frames to /content/drive/MyDrive/videos/frames_folders/concept_frames
# Moved folder concern_frames to /content/drive/MyDrive/videos/frames_folders/concern_frames
# Moved folder confront_frames to /content/drive/MyDrive/videos/frames_folders/confront_frames
# Moved folder confused_frames to /content/drive/MyDrive/videos/frames_folders/confused_frames
# Moved folder congress_frames to /content/drive/MyDrive/videos/frames_folders/congress_frames
# Moved folder connect_frames to /content/drive/MyDrive/videos/frames_folders/connect_frames
# Moved folder conquer_frames to /content/drive/MyDrive/videos/frames_folders/conquer_frames
# Moved folder constitution_frames to /content/drive/MyDrive/videos/frames_folders/constitution_frames
# Moved folder contract_frames to /content/drive/MyDrive/videos/frames_folders/contract_frames
# Moved folder court_frames to /content/drive/MyDrive/videos/frames_folders/court_frames
# Moved folder crab_frames to /content/drive/MyDrive/videos/frames_folders/crab_frames
# Moved folder cross_frames to /content/drive/MyDrive/videos/frames_folders/cross_frames
# Moved folder cruel_frames to /content/drive/MyDrive/videos/frames_folders/cruel_frames
# Moved folder crush_frames to /content/drive/MyDrive/videos/frames_folders/crush_frames
# Moved folder date_frames to /content/drive/MyDrive/videos/frames_folders/date_frames
# Moved folder december_frames to /content/drive/MyDrive/videos/frames_folders/december_frames
# Moved folder decrease_frames to /content/drive/MyDrive/videos/frames_folders/decrease_frames
# Moved folder deduct_frames to /content/drive/MyDrive/videos/frames_folders/deduct_frames
# Moved folder defeat_frames to /content/drive/MyDrive/videos/frames_folders/defeat_frames
# Moved folder deposit_frames to /content/drive/MyDrive/videos/frames_folders/deposit_frames
# Moved folder depressed_frames to /content/drive/MyDrive/videos/frames_folders/depressed_frames
# Moved folder detach_frames to /content/drive/MyDrive/videos/frames_folders/detach_frames
# Moved folder determine_frames to /content/drive/MyDrive/videos/frames_folders/determine_frames
# Moved folder diabetes_frames to /content/drive/MyDrive/videos/frames_folders/diabetes_frames
# Moved folder dime_frames to /content/drive/MyDrive/videos/frames_folders/dime_frames
# Moved folder dirt_frames to /content/drive/MyDrive/videos/frames_folders/dirt_frames
# Moved folder disgust_frames to /content/drive/MyDrive/videos/frames_folders/disgust_frames
# Moved folder dismiss_frames to /content/drive/MyDrive/videos/frames_folders/dismiss_frames
# Moved folder dizzy_frames to /content/drive/MyDrive/videos/frames_folders/dizzy_frames
# Moved folder document_frames to /content/drive/MyDrive/videos/frames_folders/document_frames
# Moved folder dorm_frames to /content/drive/MyDrive/videos/frames_folders/dorm_frames
# Moved folder dormitory_frames to /content/drive/MyDrive/videos/frames_folders/dormitory_frames
# Moved folder downstairs_frames to /content/drive/MyDrive/videos/frames_folders/downstairs_frames
# Moved folder economy_frames to /content/drive/MyDrive/videos/frames_folders/economy_frames
# Moved folder education_frames to /content/drive/MyDrive/videos/frames_folders/education_frames
# Moved folder effort_frames to /content/drive/MyDrive/videos/frames_folders/effort_frames
# Moved folder eighteen_frames to /content/drive/MyDrive/videos/frames_folders/eighteen_frames
# Moved folder engage_frames to /content/drive/MyDrive/videos/frames_folders/engage_frames
# Moved folder engagement_frames to /content/drive/MyDrive/videos/frames_folders/engagement_frames
# Moved folder engineer_frames to /content/drive/MyDrive/videos/frames_folders/engineer_frames
# Moved folder envelope_frames to /content/drive/MyDrive/videos/frames_folders/envelope_frames
# Moved folder erase_frames to /content/drive/MyDrive/videos/frames_folders/erase_frames
# Moved folder eternity_frames to /content/drive/MyDrive/videos/frames_folders/eternity_frames
# Moved folder evening_frames to /content/drive/MyDrive/videos/frames_folders/evening_frames
# Moved folder everyday_frames to /content/drive/MyDrive/videos/frames_folders/everyday_frames
# Moved folder expand_frames to /content/drive/MyDrive/videos/frames_folders/expand_frames
# Moved folder eye_frames to /content/drive/MyDrive/videos/frames_folders/eye_frames
# Moved folder eyes_frames to /content/drive/MyDrive/videos/frames_folders/eyes_frames
# Moved folder fake_frames to /content/drive/MyDrive/videos/frames_folders/fake_frames
# Moved folder farmer_frames to /content/drive/MyDrive/videos/frames_folders/farmer_frames
# Moved folder february_frames to /content/drive/MyDrive/videos/frames_folders/february_frames
# Moved folder federal_frames to /content/drive/MyDrive/videos/frames_folders/federal_frames
# Moved folder final_frames to /content/drive/MyDrive/videos/frames_folders/final_frames
# Moved folder florida_frames to /content/drive/MyDrive/videos/frames_folders/florida_frames
# Moved folder feel_frames to /content/drive/MyDrive/videos/frames_folders/feel_frames
# Moved folder football_frames to /content/drive/MyDrive/videos/frames_folders/football_frames
# Moved folder future_frames to /content/drive/MyDrive/videos/frames_folders/future_frames
# Moved folder game_frames to /content/drive/MyDrive/videos/frames_folders/game_frames
# Moved folder girl_frames to /content/drive/MyDrive/videos/frames_folders/girl_frames
# Moved folder government_frames to /content/drive/MyDrive/videos/frames_folders/government_frames
# Moved folder hear_frames to /content/drive/MyDrive/videos/frames_folders/hear_frames
# Moved folder here_frames to /content/drive/MyDrive/videos/frames_folders/here_frames
# Moved folder hope_frames to /content/drive/MyDrive/videos/frames_folders/hope_frames
# Moved folder house_frames to /content/drive/MyDrive/videos/frames_folders/house_frames
# Moved folder husband_frames to /content/drive/MyDrive/videos/frames_folders/husband_frames
# Moved folder interest_frames to /content/drive/MyDrive/videos/frames_folders/interest_frames
# Moved folder join_frames to /content/drive/MyDrive/videos/frames_folders/join_frames
# Moved folder light_frames to /content/drive/MyDrive/videos/frames_folders/light_frames
# Moved folder live_frames to /content/drive/MyDrive/videos/frames_folders/live_frames
# Moved folder make_frames to /content/drive/MyDrive/videos/frames_folders/make_frames
# Moved folder mean_frames to /content/drive/MyDrive/videos/frames_folders/mean_frames
# Moved folder more_frames to /content/drive/MyDrive/videos/frames_folders/more_frames
# Moved folder most_frames to /content/drive/MyDrive/videos/frames_folders/most_frames
# Moved folder music_frames to /content/drive/MyDrive/videos/frames_folders/music_frames
# Moved folder new_frames to /content/drive/MyDrive/videos/frames_folders/new_frames
# Moved folder none_frames to /content/drive/MyDrive/videos/frames_folders/none_frames
# Moved folder office_frames to /content/drive/MyDrive/videos/frames_folders/office_frames
# Moved folder order_frames to /content/drive/MyDrive/videos/frames_folders/order_frames
# Moved folder pants_frames to /content/drive/MyDrive/videos/frames_folders/pants_frames
# Moved folder party_frames to /content/drive/MyDrive/videos/frames_folders/party_frames
# Moved folder past_frames to /content/drive/MyDrive/videos/frames_folders/past_frames
# Moved folder pencil_frames to /content/drive/MyDrive/videos/frames_folders/pencil_frames
# Moved folder plan_frames to /content/drive/MyDrive/videos/frames_folders/plan_frames
# Moved folder please_frames to /content/drive/MyDrive/videos/frames_folders/please_frames
# Moved folder practice_frames to /content/drive/MyDrive/videos/frames_folders/practice_frames
# Moved folder president_frames to /content/drive/MyDrive/videos/frames_folders/president_frames
# Moved folder restaurant_frames to /content/drive/MyDrive/videos/frames_folders/restaurant_frames
# Moved folder ride_frames to /content/drive/MyDrive/videos/frames_folders/ride_frames
# Moved folder russia_frames to /content/drive/MyDrive/videos/frames_folders/russia_frames
# Moved folder salt_frames to /content/drive/MyDrive/videos/frames_folders/salt_frames
# Moved folder sandwich_frames to /content/drive/MyDrive/videos/frames_folders/sandwich_frames
# Moved folder sign_frames to /content/drive/MyDrive/videos/frames_folders/sign_frames
# Moved folder since_frames to /content/drive/MyDrive/videos/frames_folders/since_frames
# Moved folder small_frames to /content/drive/MyDrive/videos/frames_folders/small_frames
# Moved folder some_frames to /content/drive/MyDrive/videos/frames_folders/some_frames
# Moved folder south_frames to /content/drive/MyDrive/videos/frames_folders/south_frames
# Moved folder student_frames to /content/drive/MyDrive/videos/frames_folders/student_frames
# Moved folder teach_frames to /content/drive/MyDrive/videos/frames_folders/teach_frames
# Moved folder theory_frames to /content/drive/MyDrive/videos/frames_folders/theory_frames
# Moved folder tomato_frames to /content/drive/MyDrive/videos/frames_folders/tomato_frames
# Moved folder train_frames to /content/drive/MyDrive/videos/frames_folders/train_frames
# Moved folder ugly_frames to /content/drive/MyDrive/videos/frames_folders/ugly_frames
# Moved folder war_frames to /content/drive/MyDrive/videos/frames_folders/war_frames
# Moved folder where_frames to /content/drive/MyDrive/videos/frames_folders/where_frames
# Moved folder your_frames to /content/drive/MyDrive/videos/frames_folders/your_frames
# Moved folder always_frames to /content/drive/MyDrive/videos/frames_folders/always_frames
# Moved folder animal_frames to /content/drive/MyDrive/videos/frames_folders/animal_frames
# Moved folder argue_frames to /content/drive/MyDrive/videos/frames_folders/argue_frames
# Moved folder baby_frames to /content/drive/MyDrive/videos/frames_folders/baby_frames
# Moved folder back_frames to /content/drive/MyDrive/videos/frames_folders/back_frames
# Moved folder bake_frames to /content/drive/MyDrive/videos/frames_folders/bake_frames
# Moved folder bath_frames to /content/drive/MyDrive/videos/frames_folders/bath_frames
# Moved folder behind_frames to /content/drive/MyDrive/videos/frames_folders/behind_frames
# Moved folder bring_frames to /content/drive/MyDrive/videos/frames_folders/bring_frames
# Moved folder catch_frames to /content/drive/MyDrive/videos/frames_folders/catch_frames
# Moved folder cereal_frames to /content/drive/MyDrive/videos/frames_folders/cereal_frames
# Moved folder champion_frames to /content/drive/MyDrive/videos/frames_folders/champion_frames
# Moved folder cheese_frames to /content/drive/MyDrive/videos/frames_folders/cheese_frames
# Moved folder cough_frames to /content/drive/MyDrive/videos/frames_folders/cough_frames
# Moved folder crazy_frames to /content/drive/MyDrive/videos/frames_folders/crazy_frames
# Moved folder delay_frames to /content/drive/MyDrive/videos/frames_folders/delay_frames
# Moved folder delicious_frames to /content/drive/MyDrive/videos/frames_folders/delicious_frames
# Moved folder disappear_frames to /content/drive/MyDrive/videos/frames_folders/disappear_frames
# Moved folder divorce_frames to /content/drive/MyDrive/videos/frames_folders/divorce_frames
# Moved folder draw_frames to /content/drive/MyDrive/videos/frames_folders/draw_frames
# Moved folder east_frames to /content/drive/MyDrive/videos/frames_folders/east_frames
# Moved folder easy_frames to /content/drive/MyDrive/videos/frames_folders/easy_frames
# Moved folder egg_frames to /content/drive/MyDrive/videos/frames_folders/egg_frames
# Moved folder environment_frames to /content/drive/MyDrive/videos/frames_folders/environment_frames
# Moved folder father_frames to /content/drive/MyDrive/videos/frames_folders/father_frames
# Moved folder fault_frames to /content/drive/MyDrive/videos/frames_folders/fault_frames
# Moved folder flower_frames to /content/drive/MyDrive/videos/frames_folders/flower_frames
# Moved folder friendly_frames to /content/drive/MyDrive/videos/frames_folders/friendly_frames
# Moved folder glasses_frames to /content/drive/MyDrive/videos/frames_folders/glasses_frames
# Moved folder halloween_frames to /content/drive/MyDrive/videos/frames_folders/halloween_frames
# Moved folder hard_frames to /content/drive/MyDrive/videos/frames_folders/hard_frames
# Moved folder heart_frames to /content/drive/MyDrive/videos/frames_folders/heart_frames
# Moved folder hour_frames to /content/drive/MyDrive/videos/frames_folders/hour_frames
# Moved folder humble_frames to /content/drive/MyDrive/videos/frames_folders/humble_frames
# Moved folder hurry_frames to /content/drive/MyDrive/videos/frames_folders/hurry_frames
# Moved folder improve_frames to /content/drive/MyDrive/videos/frames_folders/improve_frames
# Moved folder internet_frames to /content/drive/MyDrive/videos/frames_folders/internet_frames
# Moved folder jump_frames to /content/drive/MyDrive/videos/frames_folders/jump_frames
# Moved folder kill_frames to /content/drive/MyDrive/videos/frames_folders/kill_frames
# Moved folder law_frames to /content/drive/MyDrive/videos/frames_folders/law_frames
# Moved folder match_frames to /content/drive/MyDrive/videos/frames_folders/match_frames
# Moved folder meat_frames to /content/drive/MyDrive/videos/frames_folders/meat_frames
# Moved folder milk_frames to /content/drive/MyDrive/videos/frames_folders/milk_frames
# Moved folder money_frames to /content/drive/MyDrive/videos/frames_folders/money_frames
# Moved folder month_frames to /content/drive/MyDrive/videos/frames_folders/month_frames
# Moved folder moon_frames to /content/drive/MyDrive/videos/frames_folders/moon_frames
# Moved folder move_frames to /content/drive/MyDrive/videos/frames_folders/move_frames
# Moved folder near_frames to /content/drive/MyDrive/videos/frames_folders/near_frames
# Moved folder nephew_frames to /content/drive/MyDrive/videos/frames_folders/nephew_frames
# Moved folder nice_frames to /content/drive/MyDrive/videos/frames_folders/nice_frames
# Moved folder niece_frames to /content/drive/MyDrive/videos/frames_folders/niece_frames
# Moved folder noon_frames to /content/drive/MyDrive/videos/frames_folders/noon_frames
# Moved folder north_frames to /content/drive/MyDrive/videos/frames_folders/north_frames
# Moved folder not_frames to /content/drive/MyDrive/videos/frames_folders/not_frames
# Moved folder nurse_frames to /content/drive/MyDrive/videos/frames_folders/nurse_frames
# Moved folder off_frames to /content/drive/MyDrive/videos/frames_folders/off_frames
# Moved folder ok_frames to /content/drive/MyDrive/videos/frames_folders/ok_frames
# Moved folder patient_frames to /content/drive/MyDrive/videos/frames_folders/patient_frames
# Moved folder pay_frames to /content/drive/MyDrive/videos/frames_folders/pay_frames
# Moved folder perspective_frames to /content/drive/MyDrive/videos/frames_folders/perspective_frames
# Moved folder potato_frames to /content/drive/MyDrive/videos/frames_folders/potato_frames
# Moved folder sad_frames to /content/drive/MyDrive/videos/frames_folders/sad_frames
# Moved folder saturday_frames to /content/drive/MyDrive/videos/frames_folders/saturday_frames
# Moved folder save_frames to /content/drive/MyDrive/videos/frames_folders/save_frames
# Moved folder scissors_frames to /content/drive/MyDrive/videos/frames_folders/scissors_frames
# Moved folder secret_frames to /content/drive/MyDrive/videos/frames_folders/secret_frames
# Moved folder shoes_frames to /content/drive/MyDrive/videos/frames_folders/shoes_frames
# Moved folder shop_frames to /content/drive/MyDrive/videos/frames_folders/shop_frames
# Moved folder silly_frames to /content/drive/MyDrive/videos/frames_folders/silly_frames
# Moved folder sister_frames to /content/drive/MyDrive/videos/frames_folders/sister_frames
# Moved folder sleep_frames to /content/drive/MyDrive/videos/frames_folders/sleep_frames
# Moved folder sorry_frames to /content/drive/MyDrive/videos/frames_folders/sorry_frames
# Moved folder straight_frames to /content/drive/MyDrive/videos/frames_folders/straight_frames
# Moved folder sweet_frames to /content/drive/MyDrive/videos/frames_folders/sweet_frames
# Moved folder talk_frames to /content/drive/MyDrive/videos/frames_folders/talk_frames
# Moved folder temperature_frames to /content/drive/MyDrive/videos/frames_folders/temperature_frames
# Moved folder tent_frames to /content/drive/MyDrive/videos/frames_folders/tent_frames
# Moved folder thank you_frames to /content/drive/MyDrive/videos/frames_folders/thank you_frames
# Moved folder recliner_frames to /content/drive/MyDrive/videos/frames_folders/recliner_frames
# Moved folder recommend_frames to /content/drive/MyDrive/videos/frames_folders/recommend_frames
# Moved folder recover_frames to /content/drive/MyDrive/videos/frames_folders/recover_frames
# Moved folder regular_frames to /content/drive/MyDrive/videos/frames_folders/regular_frames
# Moved folder release_frames to /content/drive/MyDrive/videos/frames_folders/release_frames
# Moved folder relief_frames to /content/drive/MyDrive/videos/frames_folders/relief_frames
# Moved folder rely_frames to /content/drive/MyDrive/videos/frames_folders/rely_frames
# Moved folder reply_frames to /content/drive/MyDrive/videos/frames_folders/reply_frames
# Moved folder rescue_frames to /content/drive/MyDrive/videos/frames_folders/rescue_frames
# Moved folder resist_frames to /content/drive/MyDrive/videos/frames_folders/resist_frames
# Moved folder restroom_frames to /content/drive/MyDrive/videos/frames_folders/restroom_frames
# Moved folder retreat_frames to /content/drive/MyDrive/videos/frames_folders/retreat_frames
# Moved folder roar_frames to /content/drive/MyDrive/videos/frames_folders/roar_frames
# Moved folder robber_frames to /content/drive/MyDrive/videos/frames_folders/robber_frames
# Moved folder roommate_frames to /content/drive/MyDrive/videos/frames_folders/roommate_frames
# Moved folder rose_frames to /content/drive/MyDrive/videos/frames_folders/rose_frames
# Moved folder ruin_frames to /content/drive/MyDrive/videos/frames_folders/ruin_frames
# Moved folder s_frames to /content/drive/MyDrive/videos/frames_folders/s_frames
# Moved folder salary_frames to /content/drive/MyDrive/videos/frames_folders/salary_frames
# Moved folder saw_frames to /content/drive/MyDrive/videos/frames_folders/saw_frames
# Moved folder scan_frames to /content/drive/MyDrive/videos/frames_folders/scan_frames
# Moved folder scream_frames to /content/drive/MyDrive/videos/frames_folders/scream_frames
# Moved folder sculpture_frames to /content/drive/MyDrive/videos/frames_folders/sculpture_frames
# Moved folder sea_frames to /content/drive/MyDrive/videos/frames_folders/sea_frames
# Moved folder seldom_frames to /content/drive/MyDrive/videos/frames_folders/seldom_frames
# Moved folder sequence_frames to /content/drive/MyDrive/videos/frames_folders/sequence_frames
# Moved folder settle_frames to /content/drive/MyDrive/videos/frames_folders/settle_frames
# Moved folder shout_frames to /content/drive/MyDrive/videos/frames_folders/shout_frames
# Moved folder shovel_frames to /content/drive/MyDrive/videos/frames_folders/shovel_frames
# Moved folder sin_frames to /content/drive/MyDrive/videos/frames_folders/sin_frames
# Moved folder singer_frames to /content/drive/MyDrive/videos/frames_folders/singer_frames
# Moved folder sixteen_frames to /content/drive/MyDrive/videos/frames_folders/sixteen_frames
# Moved folder ski_frames to /content/drive/MyDrive/videos/frames_folders/ski_frames
# Moved folder skip_frames to /content/drive/MyDrive/videos/frames_folders/skip_frames
# Moved folder smoking_frames to /content/drive/MyDrive/videos/frames_folders/smoking_frames
# Moved folder sofa_frames to /content/drive/MyDrive/videos/frames_folders/sofa_frames
# Moved folder soldier_frames to /content/drive/MyDrive/videos/frames_folders/soldier_frames
# Moved folder solve_frames to /content/drive/MyDrive/videos/frames_folders/solve_frames
# Moved folder someday_frames to /content/drive/MyDrive/videos/frames_folders/someday_frames
# Moved folder something_frames to /content/drive/MyDrive/videos/frames_folders/something_frames
# Moved folder somewhere_frames to /content/drive/MyDrive/videos/frames_folders/somewhere_frames
# Moved folder soul_frames to /content/drive/MyDrive/videos/frames_folders/soul_frames
# Moved folder spill_frames to /content/drive/MyDrive/videos/frames_folders/spill_frames
# Moved folder spit_frames to /content/drive/MyDrive/videos/frames_folders/spit_frames
# Moved folder spread_frames to /content/drive/MyDrive/videos/frames_folders/spread_frames
# Moved folder sprint_frames to /content/drive/MyDrive/videos/frames_folders/sprint_frames
# Moved folder squeeze_frames to /content/drive/MyDrive/videos/frames_folders/squeeze_frames
# Moved folder stadium_frames to /content/drive/MyDrive/videos/frames_folders/stadium_frames
# Moved folder stepfather_frames to /content/drive/MyDrive/videos/frames_folders/stepfather_frames
# Moved folder sting_frames to /content/drive/MyDrive/videos/frames_folders/sting_frames
# Moved folder stir_frames to /content/drive/MyDrive/videos/frames_folders/stir_frames
# Moved folder stitch_frames to /content/drive/MyDrive/videos/frames_folders/stitch_frames
# Moved folder stuck_frames to /content/drive/MyDrive/videos/frames_folders/stuck_frames
# Moved folder sue_frames to /content/drive/MyDrive/videos/frames_folders/sue_frames
# Moved folder sunshine_frames to /content/drive/MyDrive/videos/frames_folders/sunshine_frames
# Moved folder superman_frames to /content/drive/MyDrive/videos/frames_folders/superman_frames
# Moved folder surrender_frames to /content/drive/MyDrive/videos/frames_folders/surrender_frames
# Moved folder suspend_frames to /content/drive/MyDrive/videos/frames_folders/suspend_frames
# Moved folder swimming_frames to /content/drive/MyDrive/videos/frames_folders/swimming_frames
# Moved folder t_frames to /content/drive/MyDrive/videos/frames_folders/t_frames
# Moved folder talent_frames to /content/drive/MyDrive/videos/frames_folders/talent_frames
# Moved folder telescope_frames to /content/drive/MyDrive/videos/frames_folders/telescope_frames
# Moved folder tempt_frames to /content/drive/MyDrive/videos/frames_folders/tempt_frames
# Moved folder ten_frames to /content/drive/MyDrive/videos/frames_folders/ten_frames
# Moved folder tend_frames to /content/drive/MyDrive/videos/frames_folders/tend_frames
# Moved folder testify_frames to /content/drive/MyDrive/videos/frames_folders/testify_frames
# Moved folder texas_frames to /content/drive/MyDrive/videos/frames_folders/texas_frames
# Moved folder text_frames to /content/drive/MyDrive/videos/frames_folders/text_frames
# Moved folder than_frames to /content/drive/MyDrive/videos/frames_folders/than_frames
# Moved folder therefore_frames to /content/drive/MyDrive/videos/frames_folders/therefore_frames
# Moved folder thrill_frames to /content/drive/MyDrive/videos/frames_folders/thrill_frames
# Moved folder tobacco_frames to /content/drive/MyDrive/videos/frames_folders/tobacco_frames
# Moved folder toilet paper_frames to /content/drive/MyDrive/videos/frames_folders/toilet paper_frames
# Moved folder tolerate_frames to /content/drive/MyDrive/videos/frames_folders/tolerate_frames
# Moved folder torture_frames to /content/drive/MyDrive/videos/frames_folders/torture_frames
# Moved folder towel_frames to /content/drive/MyDrive/videos/frames_folders/towel_frames
# Moved folder trip_frames to /content/drive/MyDrive/videos/frames_folders/trip_frames
# Moved folder truth_frames to /content/drive/MyDrive/videos/frames_folders/truth_frames
# Moved folder turn_frames to /content/drive/MyDrive/videos/frames_folders/turn_frames
# Moved folder tv_frames to /content/drive/MyDrive/videos/frames_folders/tv_frames
# Moved folder u_frames to /content/drive/MyDrive/videos/frames_folders/u_frames
# Moved folder unique_frames to /content/drive/MyDrive/videos/frames_folders/unique_frames
# Moved folder upstairs_frames to /content/drive/MyDrive/videos/frames_folders/upstairs_frames
# Moved folder v_frames to /content/drive/MyDrive/videos/frames_folders/v_frames
# Moved folder vacant_frames to /content/drive/MyDrive/videos/frames_folders/vacant_frames
# Moved folder vague_frames to /content/drive/MyDrive/videos/frames_folders/vague_frames
# Moved folder valley_frames to /content/drive/MyDrive/videos/frames_folders/valley_frames
# Moved folder vampire_frames to /content/drive/MyDrive/videos/frames_folders/vampire_frames
# Moved folder very_frames to /content/drive/MyDrive/videos/frames_folders/very_frames
# Moved folder vice president_frames to /content/drive/MyDrive/videos/frames_folders/vice president_frames
# Moved folder viewpoint_frames to /content/drive/MyDrive/videos/frames_folders/viewpoint_frames
# Moved folder visualize_frames to /content/drive/MyDrive/videos/frames_folders/visualize_frames
# Moved folder vlog_frames to /content/drive/MyDrive/videos/frames_folders/vlog_frames
# Moved folder volleyball_frames to /content/drive/MyDrive/videos/frames_folders/volleyball_frames
# Moved folder w_frames to /content/drive/MyDrive/videos/frames_folders/w_frames
# Moved folder washington_frames to /content/drive/MyDrive/videos/frames_folders/washington_frames
# Moved folder waterfall_frames to /content/drive/MyDrive/videos/frames_folders/waterfall_frames
# Moved folder weigh_frames to /content/drive/MyDrive/videos/frames_folders/weigh_frames
# Moved folder wheelchair_frames to /content/drive/MyDrive/videos/frames_folders/wheelchair_frames
# Moved folder whistle_frames to /content/drive/MyDrive/videos/frames_folders/whistle_frames
# ...
# Moved folder chocolate_frames to /content/drive/MyDrive/videos/frames_folders/chocolate_frames
# Moved folder clean_frames to /content/drive/MyDrive/videos/frames_folders/clean_frames
# Moved folder cloud_frames to /content/drive/MyDrive/videos/frames_folders/cloud_frames
# Moved folder compare_frames to /content/drive/MyDrive/videos/frames_folders/compare_frames
# Moved folder complex_frames to /content/drive/MyDrive/videos/frames_folders/complex_frames
# Moved folder contact_frames to /content/drive/MyDrive/videos/frames_folders/contact_frames
# Moved folder continue_frames to /content/drive/MyDrive/videos/frames_folders/continue_frames
# Moved folder corner_frames to /content/drive/MyDrive/videos/frames_folders/corner_frames
# Moved folder correct_frames to /content/drive/MyDrive/videos/frames_folders/correct_frames
# Moved folder curse_frames to /content/drive/MyDrive/videos/frames_folders/curse_frames
# Moved folder dead_frames to /content/drive/MyDrive/videos/frames_folders/dead_frames
# Moved folder demand_frames to /content/drive/MyDrive/videos/frames_folders/demand_frames
# Moved folder depend_frames to /content/drive/MyDrive/videos/frames_folders/depend_frames
# Moved folder desert_frames to /content/drive/MyDrive/videos/frames_folders/desert_frames
# Moved folder desk_frames to /content/drive/MyDrive/videos/frames_folders/desk_frames
# Moved folder develop_frames to /content/drive/MyDrive/videos/frames_folders/develop_frames
# Moved folder dictionary_frames to /content/drive/MyDrive/videos/frames_folders/dictionary_frames
# Moved folder doll_frames to /content/drive/MyDrive/videos/frames_folders/doll_frames
# Moved folder duty_frames to /content/drive/MyDrive/videos/frames_folders/duty_frames
# Moved folder easter_frames to /content/drive/MyDrive/videos/frames_folders/easter_frames
# Moved folder egypt_frames to /content/drive/MyDrive/videos/frames_folders/egypt_frames
# Moved folder elevator_frames to /content/drive/MyDrive/videos/frames_folders/elevator_frames
# Moved folder email_frames to /content/drive/MyDrive/videos/frames_folders/email_frames
# Moved folder end_frames to /content/drive/MyDrive/videos/frames_folders/end_frames
# Moved folder enter_frames to /content/drive/MyDrive/videos/frames_folders/enter_frames
# Moved folder europe_frames to /content/drive/MyDrive/videos/frames_folders/europe_frames
# Moved folder event_frames to /content/drive/MyDrive/videos/frames_folders/event_frames
# Moved folder exchange_frames to /content/drive/MyDrive/videos/frames_folders/exchange_frames
# Moved folder experience_frames to /content/drive/MyDrive/videos/frames_folders/experience_frames
# Moved folder face_frames to /content/drive/MyDrive/videos/frames_folders/face_frames
# Moved folder fail_frames to /content/drive/MyDrive/videos/frames_folders/fail_frames
# Moved folder feed_frames to /content/drive/MyDrive/videos/frames_folders/feed_frames
# Moved folder few_frames to /content/drive/MyDrive/videos/frames_folders/few_frames
# Moved folder flag_frames to /content/drive/MyDrive/videos/frames_folders/flag_frames
# Moved folder food_frames to /content/drive/MyDrive/videos/frames_folders/food_frames
# Moved folder for_frames to /content/drive/MyDrive/videos/frames_folders/for_frames
# Moved folder form_frames to /content/drive/MyDrive/videos/frames_folders/form_frames
# Moved folder freeze_frames to /content/drive/MyDrive/videos/frames_folders/freeze_frames
# Moved folder friday_frames to /content/drive/MyDrive/videos/frames_folders/friday_frames
# Moved folder front_frames to /content/drive/MyDrive/videos/frames_folders/front_frames
# Moved folder giraffe_frames to /content/drive/MyDrive/videos/frames_folders/giraffe_frames
# Moved folder god_frames to /content/drive/MyDrive/videos/frames_folders/god_frames
# Moved folder grammar_frames to /content/drive/MyDrive/videos/frames_folders/grammar_frames
# Moved folder grandfather_frames to /content/drive/MyDrive/videos/frames_folders/grandfather_frames
# Moved folder great_frames to /content/drive/MyDrive/videos/frames_folders/great_frames
# Moved folder greece_frames to /content/drive/MyDrive/videos/frames_folders/greece_frames
# Moved folder guess_frames to /content/drive/MyDrive/videos/frames_folders/guess_frames
# Moved folder guitar_frames to /content/drive/MyDrive/videos/frames_folders/guitar_frames
# Moved folder hammer_frames to /content/drive/MyDrive/videos/frames_folders/hammer_frames
# Moved folder helicopter_frames to /content/drive/MyDrive/videos/frames_folders/helicopter_frames
# Moved folder high_frames to /content/drive/MyDrive/videos/frames_folders/high_frames
# Moved folder history_frames to /content/drive/MyDrive/videos/frames_folders/history_frames
# Moved folder hungry_frames to /content/drive/MyDrive/videos/frames_folders/hungry_frames
# Moved folder hurt_frames to /content/drive/MyDrive/videos/frames_folders/hurt_frames
# Moved folder introduce_frames to /content/drive/MyDrive/videos/frames_folders/introduce_frames
# Moved folder invest_frames to /content/drive/MyDrive/videos/frames_folders/invest_frames
# Moved folder lazy_frames to /content/drive/MyDrive/videos/frames_folders/lazy_frames
# Moved folder library_frames to /content/drive/MyDrive/videos/frames_folders/library_frames
# Moved folder lie_frames to /content/drive/MyDrive/videos/frames_folders/lie_frames
# Moved folder lobster_frames to /content/drive/MyDrive/videos/frames_folders/lobster_frames
# Moved folder love_frames to /content/drive/MyDrive/videos/frames_folders/love_frames
# Moved folder lucky_frames to /content/drive/MyDrive/videos/frames_folders/lucky_frames
# Moved folder magazine_frames to /content/drive/MyDrive/videos/frames_folders/magazine_frames
# Moved folder measure_frames to /content/drive/MyDrive/videos/frames_folders/measure_frames
# Moved folder microwave_frames to /content/drive/MyDrive/videos/frames_folders/microwave_frames
# Moved folder my_frames to /content/drive/MyDrive/videos/frames_folders/my_frames
# Moved folder neighbor_frames to /content/drive/MyDrive/videos/frames_folders/neighbor_frames
# Moved folder number_frames to /content/drive/MyDrive/videos/frames_folders/number_frames
# Moved folder one_frames to /content/drive/MyDrive/videos/frames_folders/one_frames
# Moved folder outside_frames to /content/drive/MyDrive/videos/frames_folders/outside_frames
# Moved folder paint_frames to /content/drive/MyDrive/videos/frames_folders/paint_frames
# Moved folder paper_frames to /content/drive/MyDrive/videos/frames_folders/paper_frames
# Moved folder pull_frames to /content/drive/MyDrive/videos/frames_folders/pull_frames
# Moved folder purple_frames to /content/drive/MyDrive/videos/frames_folders/purple_frames
# Moved folder right_frames to /content/drive/MyDrive/videos/frames_folders/right_frames
# Moved folder same_frames to /content/drive/MyDrive/videos/frames_folders/same_frames
# Moved folder son_frames to /content/drive/MyDrive/videos/frames_folders/son_frames
# Moved folder tell_frames to /content/drive/MyDrive/videos/frames_folders/tell_frames
# Moved folder thursday_frames to /content/drive/MyDrive/videos/frames_folders/thursday_frames
# Moved folder visit_frames to /content/drive/MyDrive/videos/frames_folders/visit_frames
# Moved folder wait_frames to /content/drive/MyDrive/videos/frames_folders/wait_frames
# Moved folder water_frames to /content/drive/MyDrive/videos/frames_folders/water_frames
# Moved folder wife_frames to /content/drive/MyDrive/videos/frames_folders/wife_frames
# Moved folder backpack_frames to /content/drive/MyDrive/videos/frames_folders/backpack_frames
# Moved folder bar_frames to /content/drive/MyDrive/videos/frames_folders/bar_frames
# Moved folder brother_frames to /content/drive/MyDrive/videos/frames_folders/brother_frames
# Moved folder cat_frames to /content/drive/MyDrive/videos/frames_folders/cat_frames
# Moved folder check_frames to /content/drive/MyDrive/videos/frames_folders/check_frames
# Moved folder class_frames to /content/drive/MyDrive/videos/frames_folders/class_frames
# Moved folder cry_frames to /content/drive/MyDrive/videos/frames_folders/cry_frames
# Moved folder different_frames to /content/drive/MyDrive/videos/frames_folders/different_frames
# Moved folder door_frames to /content/drive/MyDrive/videos/frames_folders/door_frames
# Moved folder green_frames to /content/drive/MyDrive/videos/frames_folders/green_frames
# Moved folder hair_frames to /content/drive/MyDrive/videos/frames_folders/hair_frames
# Moved folder have_frames to /content/drive/MyDrive/videos/frames_folders/have_frames
# Moved folder headache_frames to /content/drive/MyDrive/videos/frames_folders/headache_frames
# Moved folder inform_frames to /content/drive/MyDrive/videos/frames_folders/inform_frames
# Moved folder knife_frames to /content/drive/MyDrive/videos/frames_folders/knife_frames
# Moved folder laugh_frames to /content/drive/MyDrive/videos/frames_folders/laugh_frames
# Moved folder learn_frames to /content/drive/MyDrive/videos/frames_folders/learn_frames
# Moved folder movie_frames to /content/drive/MyDrive/videos/frames_folders/movie_frames
# Moved folder rabbit_frames to /content/drive/MyDrive/videos/frames_folders/rabbit_frames
# Moved folder read_frames to /content/drive/MyDrive/videos/frames_folders/read_frames
# Moved folder red_frames to /content/drive/MyDrive/videos/frames_folders/red_frames
# Moved folder room_frames to /content/drive/MyDrive/videos/frames_folders/room_frames
# Moved folder run_frames to /content/drive/MyDrive/videos/frames_folders/run_frames
# Moved folder show_frames to /content/drive/MyDrive/videos/frames_folders/show_frames
# Moved folder sick_frames to /content/drive/MyDrive/videos/frames_folders/sick_frames
# Moved folder snow_frames to /content/drive/MyDrive/videos/frames_folders/snow_frames
# Moved folder take_frames to /content/drive/MyDrive/videos/frames_folders/take_frames
# Moved folder tea_frames to /content/drive/MyDrive/videos/frames_folders/tea_frames
# Moved folder teacher_frames to /content/drive/MyDrive/videos/frames_folders/teacher_frames
# Moved folder week_frames to /content/drive/MyDrive/videos/frames_folders/week_frames
# Moved folder why_frames to /content/drive/MyDrive/videos/frames_folders/why_frames
# Moved folder with_frames to /content/drive/MyDrive/videos/frames_folders/with_frames
# Moved folder write_frames to /content/drive/MyDrive/videos/frames_folders/write_frames
# Moved folder again_frames to /content/drive/MyDrive/videos/frames_folders/again_frames
# Moved folder bad_frames to /content/drive/MyDrive/videos/frames_folders/bad_frames
# Moved folder ball_frames to /content/drive/MyDrive/videos/frames_folders/ball_frames
# Moved folder bathroom_frames to /content/drive/MyDrive/videos/frames_folders/bathroom_frames
# Moved folder blanket_frames to /content/drive/MyDrive/videos/frames_folders/blanket_frames
# Moved folder buy_frames to /content/drive/MyDrive/videos/frames_folders/buy_frames
# Moved folder call_frames to /content/drive/MyDrive/videos/frames_folders/call_frames
# Moved folder coffee_frames to /content/drive/MyDrive/videos/frames_folders/coffee_frames
# Moved folder cold_frames to /content/drive/MyDrive/videos/frames_folders/cold_frames
# Moved folder college_frames to /content/drive/MyDrive/videos/frames_folders/college_frames
# Moved folder copy_frames to /content/drive/MyDrive/videos/frames_folders/copy_frames
# Moved folder cute_frames to /content/drive/MyDrive/videos/frames_folders/cute_frames
# Moved folder daughter_frames to /content/drive/MyDrive/videos/frames_folders/daughter_frames
# Moved folder example_frames to /content/drive/MyDrive/videos/frames_folders/example_frames
# Moved folder far_frames to /content/drive/MyDrive/videos/frames_folders/far_frames
# Moved folder first_frames to /content/drive/MyDrive/videos/frames_folders/first_frames
# Moved folder friend_frames to /content/drive/MyDrive/videos/frames_folders/friend_frames
# Moved folder good_frames to /content/drive/MyDrive/videos/frames_folders/good_frames
# Moved folder happy_frames to /content/drive/MyDrive/videos/frames_folders/happy_frames
# Moved folder home_frames to /content/drive/MyDrive/videos/frames_folders/home_frames
# Moved folder know_frames to /content/drive/MyDrive/videos/frames_folders/know_frames
# Moved folder late_frames to /content/drive/MyDrive/videos/frames_folders/late_frames
# Moved folder leave_frames to /content/drive/MyDrive/videos/frames_folders/leave_frames
# Moved folder list_frames to /content/drive/MyDrive/videos/frames_folders/list_frames
# Moved folder lose_frames to /content/drive/MyDrive/videos/frames_folders/lose_frames
# Moved folder name_frames to /content/drive/MyDrive/videos/frames_folders/name_frames
# Moved folder old_frames to /content/drive/MyDrive/videos/frames_folders/old_frames
# Moved folder person_frames to /content/drive/MyDrive/videos/frames_folders/person_frames
# Moved folder police_frames to /content/drive/MyDrive/videos/frames_folders/police_frames
# Moved folder problem_frames to /content/drive/MyDrive/videos/frames_folders/problem_frames
# Moved folder remember_frames to /content/drive/MyDrive/videos/frames_folders/remember_frames
# Moved folder share_frames to /content/drive/MyDrive/videos/frames_folders/share_frames
# Moved folder soon_frames to /content/drive/MyDrive/videos/frames_folders/soon_frames
# Moved folder stay_frames to /content/drive/MyDrive/videos/frames_folders/stay_frames
# Moved folder sunday_frames to /content/drive/MyDrive/videos/frames_folders/sunday_frames
# Moved folder test_frames to /content/drive/MyDrive/videos/frames_folders/test_frames
# Moved folder tired_frames to /content/drive/MyDrive/videos/frames_folders/tired_frames
# Moved folder trade_frames to /content/drive/MyDrive/videos/frames_folders/trade_frames
# Moved folder travel_frames to /content/drive/MyDrive/videos/frames_folders/travel_frames
# Moved folder window_frames to /content/drive/MyDrive/videos/frames_folders/window_frames
# Moved folder you_frames to /content/drive/MyDrive/videos/frames_folders/you_frames
# Moved folder about_frames to /content/drive/MyDrive/videos/frames_folders/about_frames
# Moved folder approve_frames to /content/drive/MyDrive/videos/frames_folders/approve_frames
# Moved folder arrive_frames to /content/drive/MyDrive/videos/frames_folders/arrive_frames
# Moved folder balance_frames to /content/drive/MyDrive/videos/frames_folders/balance_frames
# Moved folder banana_frames to /content/drive/MyDrive/videos/frames_folders/banana_frames
# Moved folder beard_frames to /content/drive/MyDrive/videos/frames_folders/beard_frames
# Moved folder because_frames to /content/drive/MyDrive/videos/frames_folders/because_frames
# Moved folder boy_frames to /content/drive/MyDrive/videos/frames_folders/boy_frames
# Moved folder business_frames to /content/drive/MyDrive/videos/frames_folders/business_frames
# Moved folder careful_frames to /content/drive/MyDrive/videos/frames_folders/careful_frames
# Moved folder center_frames to /content/drive/MyDrive/videos/frames_folders/center_frames
# Moved folder chat_frames to /content/drive/MyDrive/videos/frames_folders/chat_frames
# Moved folder children_frames to /content/drive/MyDrive/videos/frames_folders/children_frames
# Moved folder christmas_frames to /content/drive/MyDrive/videos/frames_folders/christmas_frames
# Moved folder clock_frames to /content/drive/MyDrive/videos/frames_folders/clock_frames
# Moved folder close_frames to /content/drive/MyDrive/videos/frames_folders/close_frames
# Moved folder convince_frames to /content/drive/MyDrive/videos/frames_folders/convince_frames
# Moved folder country_frames to /content/drive/MyDrive/videos/frames_folders/country_frames
# Moved folder crash_frames to /content/drive/MyDrive/videos/frames_folders/crash_frames
# Moved folder day_frames to /content/drive/MyDrive/videos/frames_folders/day_frames
# Moved folder discuss_frames to /content/drive/MyDrive/videos/frames_folders/discuss_frames
# Moved folder dress_frames to /content/drive/MyDrive/videos/frames_folders/dress_frames
# Moved folder drive_frames to /content/drive/MyDrive/videos/frames_folders/drive_frames
# Moved folder drop_frames to /content/drive/MyDrive/videos/frames_folders/drop_frames
# Moved folder fat_frames to /content/drive/MyDrive/videos/frames_folders/fat_frames

# %%
import os
import random
import shutil

# Set the path to the folder containing the images
data_path = "/content/drive/MyDrive/frames_newfolder"

# Define the output paths for training and testing data
train_path = "/content/drive/MyDrive/train_dataset"
test_path = "/content/drive/MyDrive/test_dataset"

# Set the test split ratio
test_split_ratio = 0.2

# Create the train and test directories if they don't exist
os.makedirs(train_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)

# Iterate over the subfolders in the data folder
for foldername in os.listdir(data_path):
    folder_path = os.path.join(data_path, foldername)
    if os.path.isdir(folder_path):
        # Create train and test subdirectories in the output folders
        train_folder = os.path.join(train_path, foldername)
        test_folder = os.path.join(test_path, foldername)
        os.makedirs(train_folder, exist_ok=True)
        os.makedirs(test_folder, exist_ok=True)

        # Iterate over the images in the subfolder
        for filename in os.listdir(folder_path):
            if filename.endswith(".jpg") or filename.endswith(".png"):  # Adjust the file extensions as per your images
                file_path = os.path.join(folder_path, filename)

                # Randomly assign to train or test set based on the split ratio
                if random.uniform(0, 1) < test_split_ratio:
                    destination = os.path.join(test_folder, filename)
                else:
                    destination = os.path.join(train_folder, filename)

                # Move the image to the respective directory
                shutil.move(file_path, destination)

print("Train-test split completed successfully.")
# Out:
# Train-test split completed successfully.

# %% [markdown]
# # Feature extraction using VGG16

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt


size = [224, 224]

# %%
training_data = '/content/drive/MyDrive/train_frames'
test_data = '/content/drive/MyDrive/test_frames'

# %%
vgg = VGG16(input_shape=size + [3], weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
x = Flatten()(vgg.output)
prediction = Dense(12, activation='softmax')(x)

# %%
model = Model(inputs=vgg.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 12)                301068
#
# =================================================================
# Total params: 15,015,756
# Trainable params: 301,068
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator


train_img = ImageDataGenerator(rescale = 1./255,shear_range = 0.25,zoom_range = 0.3)


test_img = ImageDataGenerator(rescale = 1./255)


training_set = train_img.flow_from_directory('/content/drive/MyDrive/train_frames',target_size = (224, 224),batch_size = 32,class_mode = 'categorical')

testing_set = test_img.flow_from_directory('/content/drive/MyDrive/test_frames',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 2847 images belonging to 12 classes.
# Found 713 images belonging to 12 classes.

# %%
r = model.fit(
  training_set,
  validation_data=testing_set,
  epochs=7,
  steps_per_epoch=len(training_set),
  validation_steps=len(testing_set)
)
# Out:
# Epoch 1/7
# 89/89 [==============================] - 2670s 30s/step - loss: 0.8951 - accuracy: 0.7302 - val_loss: 0.2589 - val_accuracy: 0.9060
# Epoch 2/7
# 89/89 [==============================] - 2123s 24s/step - loss: 0.2304 - accuracy: 0.9220 - val_loss: 0.1721 - val_accuracy: 0.9453
# Epoch 3/7
# 89/89 [==============================] - 2118s 24s/step - loss: 0.1748 - accuracy: 0.9389 - val_loss: 0.1312 - val_accuracy: 0.9523
# Epoch 4/7
# 89/89 [==============================] - 2172s 24s/step - loss: 0.1434 - accuracy: 0.9522 - val_loss: 0.1475 - val_accuracy: 0.9397
# Epoch 5/7
# 89/89 [==============================] - 2183s 25s/step - loss: 0.1226 - accuracy: 0.9575 - val_loss: 0.1345 - val_accuracy: 0.9579
# Epoch 6/7
# 89/89 [==============================] - 2206s 25s/step - loss: 0.1238 - accuracy: 0.9557 - val_loss: 0.1107 - val_accuracy: 0.9607
# Epoch 7/7
# 89/89 [==============================] - 2219s 25s/step - loss: 0.0924 - accuracy: 0.9680 - val_loss: 0.0786 - val_accuracy: 0.9804

# %%
from tensorflow import keras

# Assuming you have a trained model named 'model'
# ...

# Save the model
model.save("model.h5")

# %%
model.save("/content/drive/MyDrive/models/sign_language.h5")

# %% [markdown]
# # Validating the model

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/models/sign_language.h5')

# %%
# !pip install keras

# %%
# !pip install tensorflow.keras

# %%
# !pip install --upgrade torch

# %%
# !pip3 install --upgrade python

# %%
# !pip install tensorflow 2.8.0

# %%
import cv2
import numpy as np
import imageio
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.models import load_model

# Load the pre-trained VGG16 model
model = load_model('/content/drive/MyDrive/models/sign_language.h5')  # Replace with the path to your VGG model file

# Define the class labels for sign language translation
class_labels = ['yellow', 'deaf', 'deaf','yellow','yellow','yellow', 'yellow','yellow', 'yellow', 'yellow','yellow','deaf']  # Replace with your class labels

# Function to convert an image to an array
def image_to_array(image_path):
    img = imageio.imread(image_path)
    img_array = np.array(img)
    return img_array

# Function to preprocess frames using contrast stretching
def preprocess_frame(frame):
    frame = cv2.resize(frame, (224, 224))
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    min_val = np.min(frame)
    max_val = np.max(frame)
    frame = (frame - min_val) / (max_val - min_val)
    return frame


# Function to predict the label for a given frame
def predict_label(frame):
    preprocessed_frame = preprocess_frame(frame)
    preprocessed_frame = np.expand_dims(preprocessed_frame, axis=0)
    prediction = model.predict(preprocessed_frame)
    predicted_label = class_labels[np.argmax(prediction)]
    return predicted_label

# Function to process the input video
def process_video(video_path):
    video = cv2.VideoCapture(video_path)
    while video.isOpened():
        ret, frame = video.read()
        if not ret:
            break
        predicted_label = predict_label(frame)
        print("Predicted Label:", predicted_label)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    video.release()
    cv2.destroyAllWindows()

# Provide the path to your input video
input_video_path = '/content/drive/MyDrive/yellowbypranay.mp4'

# Process the input video and print the predicted labels
process_video(input_video_path)
# Out:
# 1/1 [==============================] - 0s 162ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 25ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 33ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 39ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 38ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 31ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 30ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 30ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 42ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 48ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 29ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 30ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 31ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 30ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 35ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 30ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 29ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 28ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 27ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 31ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 32ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 26ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 24ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 17ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 25ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 25ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 17ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 18ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 20ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 22ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 21ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 23ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 17ms/step
# Predicted Label: yellow
# 1/1 [==============================] - 0s 19ms/step
# Predicted Label: yellow
